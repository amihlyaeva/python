# %% [markdown]
# <a href="https://colab.research.google.com/github/amihlyaeva/python/blob/main/Web%20scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Домашняя работа Web scraping.
#
# 1.Контекст:
# Я явлюсь аналитиком небольшой строительной компании, которая занимается строительством коттеджей под заказ. Предлагаю, для улучшения планирования работ, использовать современные системы управления данными. Для наилучшего распределения работников по объектам строительства и единиц техники, использовать анализ погодных условий. Если погодные условия плохие (по прогнозу предвещаются осадки или температура ниже 0 градусов), то люди в основном распределяются по объектам с внутренними отделочно-строительные работами, техника на очередной мелкий ремонт. Иначе на внешние строительные работы с использованием техники. Все решения пишутся с возможностью будущего расширения и открытия филиалов.
# Для получения данных о погоде использовать бесплатный ресурс Gismeteo.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.gismeteo.ru/weather-chelyabinsk-4565/now/'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:121.0) Gecko/20100101 Firefox/121.0",
}
response = requests.get(url, headers=headers)
bs = BeautifulSoup(response.text, 'lxml')

bs
# Out:
# <!DOCTYPE html>
# ...

# %%
# @title Текст заголовка по умолчанию
temp = bs.find('span', class_='unit_temperature_c')
print(temp)
# Out:
# None

# %%
3. Структура данных, которая будет хранить в таблице реляционной базы данных.

https://lucid.app/lucidchart/d7dd81d3-2eca-4c4a-b789-378d27054037/edit?viewport_loc=-736%2C-96%2C2663%2C1361%2C0_0&invitationId=inv_27ec1c2f-b11b-4f80-93c7-d7e50a0a5bdc

# %% [markdown]
# Описание модели данных на уровне концепта
#
# https://lucid.app/lucidchart/778f00a6-021b-415b-9e5e-93b1c776c6a1/edit?view_items=I3C6ZUM3FRLU&invitationId=inv_de2247cd-b0de-429c-8a6e-d202e94ae71f

# %% [markdown]
# Ресурсы(hardware), которые понадобятся, чтобы реализовать мою идею.
# Наша компания не большая до 50 пользователей. С точки зрения построения серверной инфраструктуры, значительно удобнее делать это на виртуальных машинах, поскольку можем выделить ресурсов ровно столько, сколько нужно сейчас и не нести лишние затраты на резерв.
#
# Ноутбук с подключением к интернету.
